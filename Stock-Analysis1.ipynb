# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\varsh\Downloads\GOOG.csv")
df
# Out:
#             date      open      high       low     close     volume StockName
# 0     19-08-2004    2.4989    2.6001    2.3977    2.5070  893180000    Google
# 1     20-08-2004    2.5239    2.7255    2.5112    2.7063  456686000    Google
# 2     23-08-2004    2.7675    2.8355    2.7248    2.7335  365122000    Google
# 3     24-08-2004    2.7795    2.7885    2.5879    2.6203  304946000    Google
# 4     25-08-2004    2.6176    2.6986    2.5956    2.6486  183772000    Google
# ...          ...       ...       ...       ...       ...        ...       ...
# 5124  27-12-2024  194.9500  195.3200  190.6500  192.7600   18891362    Google
# 5125  30-12-2024  189.8000  192.5500  189.1200  191.2400   14264659    Google
# 5126  31-12-2024  191.0750  191.9600  188.5100  189.3000   17466919    Google
# 5127  02-01-2025  190.6500  192.0000  187.5000  189.4300   20370828    Google
# 5128  03-01-2025  191.3700  193.2100  189.9750  191.7900   18596159    Google
#
# [5129 rows x 7 columns]

# %%
print(df.info())  
print(df.describe())  
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5129 entries, 0 to 5128
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       5129 non-null   object
#  1   open       5129 non-null   float64
#  2   high       5129 non-null   float64
#  3   low        5129 non-null   float64
#  4   close      5129 non-null   float64
#  5   volume     5129 non-null   int64
#  6   StockName  5129 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 280.6+ KB
# None
#               open         high          low        close        volume
# count  5129.000000  5129.000000  5129.000000  5129.000000  5.129000e+03
# mean     47.799165    48.301353    47.305876    47.813100  1.154472e+08
# std      46.024292    46.531925    45.551566    46.048888  1.469858e+08
# min       2.475900     2.542100     2.397700     2.498900  9.312760e+06
# ...

# %%
df1 = df['open'].rolling(10).mean()
df1
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5124    193.1315
# 5125    193.0105
# 5126    192.8310
# 5127    192.1710
# 5128    191.7860
# Name: open, Length: 5129, dtype: float64

# %%
df2 = df1.iloc[-1]
df2
# Out:
# 191.786

# %%
df1.plot()
# Out:
# <Axes: >

# %%
numeric_data = df[['open', 'close', 'high', 'low', 'volume']]

# Step 3: Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Step 4: Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Stock Metrics')
plt.show()

# %%
df['DPR'] = ((df['close'] - df['open']) / df['open']) * 100
df['DPR']
# Out:
# 0       0.324143
# 1       7.226911
# 2      -1.228546
# 3      -5.727649
# 4       1.184291
#           ...
# 5124   -1.123365
# 5125    0.758693
# 5126   -0.928955
# 5127   -0.639916
# 5128    0.219470
# Name: DPR, Length: 5129, dtype: float64

# %%
df['DPR'].plot()
# Out:
# <Axes: >

# %%
df2 = pd.read_csv(r"C:\Users\varsh\Downloads\APPL 1 .csv")
df2
# Out:
#             Date   Price    Open    High     Low     Vol. Change % StockName
# 0     07-01-2025  242.21  242.98  245.55  241.35   40.86M   -1.14%     Apple
# 1     06-01-2025  245.00  244.31  247.33  243.20   45.05M    0.67%     Apple
# 2     03-01-2025  243.36  243.36  244.18  241.89   40.24M   -0.20%     Apple
# 3     02-01-2025  243.85  248.93  249.10  241.82   55.74M   -2.62%     Apple
# 4     31-12-2024  250.42  252.44  253.28  249.43   39.48M   -0.71%     Apple
# ...          ...     ...     ...     ...     ...      ...      ...       ...
# 1257  08-01-2020   75.80   74.29   76.11   74.29  132.36M    1.61%     Apple
# 1258  07-01-2020   74.60   74.96   75.22   74.37  111.51M   -0.47%     Apple
# 1259  06-01-2020   74.95   73.45   74.99   73.19  118.58M    0.79%     Apple
# 1260  03-01-2020   74.36   74.29   75.14   74.12  146.54M   -0.97%     Apple
# 1261  02-01-2020   75.09   74.06   75.15   73.80  135.65M    2.29%     Apple
#
# [1262 rows x 8 columns]

# %%
print(df2.info())  
print(df2.describe())  
print(df2.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262 entries, 0 to 1261
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1262 non-null   object
#  1   Price      1262 non-null   float64
#  2   Open       1262 non-null   float64
#  3   High       1262 non-null   float64
#  4   Low        1262 non-null   float64
#  5   Vol.       1262 non-null   object
#  6   Change %   1262 non-null   object
#  7   StockName  1262 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 79.0+ KB
# None
#              Price         Open         High          Low
# count  1262.000000  1262.000000  1262.000000  1262.000000
# mean    154.392393   154.239897   155.948201   152.663106
# std      41.759430    41.715461    41.901072    41.547626
# min      56.090000    57.020000    57.120000    53.150000
# 25%     129.657500   129.192500   130.892500   127.762500
# ...

# %%
df3 = df2['Open'].rolling(10).mean()
df3
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 1257    78.020
# 1258    77.552
# 1259    76.967
# 1260    76.489
# 1261    76.055
# Name: Open, Length: 1262, dtype: float64

# %%
df3.plot()
# Out:
# <Axes: >

# %%
numeric_data = df2[['Open', 'Price', 'High', 'Low']]

# Step 3: Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Step 4: Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Greens', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Stock Metrics')
plt.show()

# %%
df2['DPR'] = ((df2['Price'] - df2['Open']) / df2['Open']) * 100
df2['DPR']
# Out:
# 0      -0.316899
# 1       0.282428
# 2       0.000000
# 3      -2.040734
# 4      -0.800190
#           ...
# 1257    2.032575
# 1258   -0.480256
# 1259    2.042206
# 1260    0.094225
# 1261    1.390764
# Name: DPR, Length: 1262, dtype: float64

# %%
df2['DPR'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
df4 = pd.read_csv(r"C:\Users\varsh\Downloads\AMZN 1.csv")
df4
# Out:
#             Date   Price    Open    High     Low    Vol. Change % StockName
# 0     07-01-2025  222.11  227.90  228.38  221.46  28.08M   -2.42%    Amazon
# 1     06-01-2025  227.61  226.78  228.84  224.84  31.85M    1.53%    Amazon
# 2     03-01-2025  224.19  222.51  225.36  221.62  27.52M    1.80%    Amazon
# 3     02-01-2025  220.22  222.03  225.15  218.19  33.96M    0.38%    Amazon
# 4     31-12-2024  219.39  222.96  223.23  218.94  24.82M   -0.86%    Amazon
# ...          ...     ...     ...     ...     ...     ...      ...       ...
# 1257  08-01-2020   94.60   94.90   95.55   94.32  70.24M   -0.78%    Amazon
# 1258  07-01-2020   95.34   95.22   95.69   94.60  82.68M    0.21%    Amazon
# 1259  06-01-2020   95.14   93.00   95.18   93.00  81.31M    1.48%    Amazon
# 1260  03-01-2020   93.75   93.22   94.31   93.22  75.33M   -1.21%    Amazon
# 1261  02-01-2020   94.90   93.75   94.90   93.21  80.72M    2.72%    Amazon
#
# [1262 rows x 8 columns]

# %%
print(df4.info())  
print(df4.describe())  
print(df4.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262 entries, 0 to 1261
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1262 non-null   object
#  1   Price      1262 non-null   float64
#  2   Open       1262 non-null   float64
#  3   High       1262 non-null   float64
#  4   Low        1262 non-null   float64
#  5   Vol.       1262 non-null   object
#  6   Change %   1262 non-null   object
#  7   StockName  1262 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 79.0+ KB
# None
#              Price         Open         High          Low
# count  1262.000000  1262.000000  1262.000000  1262.000000
# mean    146.957227   146.987124   148.786125   145.074445
# std      32.244954    32.315493    32.375463    32.138925
# min      81.820000    82.080000    83.480000    81.300000
# 25%     121.090000   120.885000   122.940000   119.172500
# ...

# %%
df5 = df4['Open'].rolling(10).mean()
df5
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 1257    94.462
# 1258    94.504
# 1259    94.479
# 1260    94.372
# 1261    94.332
# Name: Open, Length: 1262, dtype: float64

# %%
df5.plot()
# Out:
# <Axes: >

# %%
numeric_data = df4[['Open', 'Price', 'High', 'Low']]

# Step 3: Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Step 4: Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Reds', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Stock Metrics')
plt.show()

# %%
df4['DPR'] = ((df4['Price'] - df4['Open']) / df4['Open']) * 100
df4['DPR']
# Out:
# 0      -2.540588
# 1       0.365993
# 2       0.755022
# 3      -0.815205
# 4      -1.601184
#           ...
# 1257   -0.316122
# 1258    0.126024
# 1259    2.301075
# 1260    0.568548
# 1261    1.226667
# Name: DPR, Length: 1262, dtype: float64

# %%
df4['DPR'].plot()
# Out:
# <Axes: >

# %%
df6 = pd.read_csv(r"C:\Users\varsh\Downloads\MSFT 1.csv")
df6
# Out:
#             Date  Close/Last    Volume     Open     High       Low  StockName
# 0     01-07-2025      422.37  18139070  429.000  430.650  420.8000  Microsoft
# 1     01-06-2025      427.85  20573650  428.000  434.320  425.4774  Microsoft
# 2     01-03-2025      423.35  16662940  421.080  424.030  419.5400  Microsoft
# 3     01-02-2025      418.58  16896470  425.530  426.070  414.8500  Microsoft
# 4     12/31/2024      421.50  13246510  426.100  426.730  420.6600  Microsoft
# ...          ...         ...       ...      ...      ...       ...        ...
# 1253  01/14/2020      162.13  23500780  163.390  163.600  161.7200  Microsoft
# 1254  01/13/2020      163.28  21637010  161.760  163.310  161.2600  Microsoft
# 1255  01-10-2020      161.34  20733950  162.824  163.220  161.1800  Microsoft
# 1256  01-09-2020      162.09  21399950  161.835  162.215  161.0300  Microsoft
# 1257  01-08-2020      160.09  27762030  158.930  160.800  157.9491  Microsoft
#
# [1258 rows x 7 columns]

# %%
print(df6.info())  
print(df6.describe())  
print(df6.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1258 non-null   object
#  1   Close/Last  1258 non-null   float64
#  2   Volume      1258 non-null   int64
#  3   Open        1258 non-null   float64
#  4   High        1258 non-null   float64
#  5   Low         1258 non-null   float64
#  6   StockName   1258 non-null   object
#  7   DPR         1258 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 78.8+ KB
# None
#         Close/Last        Volume         Open         High          Low  \
# count  1258.000000  1.258000e+03  1258.000000  1258.000000  1258.000000
# mean    295.177758  2.863101e+07   295.112666   298.039238   292.066160
# std      80.127869  1.274821e+07    80.211730    80.375240    79.818609
# min     135.420000  7.164543e+06   137.010000   140.570000   132.520000
# ...

# %%
df7 = df6['Open'].rolling(10).mean()
df7
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 1253    165.0490
# 1254    164.8470
# 1255    165.0144
# 1256    164.4469
# 1257    163.7209
# Name: Open, Length: 1258, dtype: float64

# %%
df7.plot()
# Out:
# <Axes: >

# %%
numeric_data = df6[['Open', 'Close/Last', 'High', 'Low', 'Volume']]

# Step 3: Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Step 4: Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Oranges', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Stock Metrics')
plt.show()

# %%
df6['DPR'] = ((df6['Close/Last'] - df6['Open']) / df6['Open']) * 100
df6['DPR']
# Out:
# 0      -1.545455
# 1      -0.035047
# 2       0.539090
# 3      -1.633257
# 4      -1.079559
#           ...
# 1253   -0.771161
# 1254    0.939664
# 1255   -0.911414
# 1256    0.157568
# 1257    0.729881
# Name: DPR, Length: 1258, dtype: float64

# %%
df6['DPR'].plot()
# Out:
# <Axes: >

# %%
df8 = pd.read_csv(r"C:\Users\varsh\Downloads\TSLA.csv")
df8
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     07-01-2025  394.36  405.83  414.33  390.00   75.70M   -4.06%
# 1     06-01-2025  411.05  423.20  426.43  401.70   85.52M    0.15%
# 2     03-01-2025  410.44  381.48  411.88  379.45   95.42M    8.22%
# 3     02-01-2025  379.28  390.10  392.73  373.04  109.71M   -6.08%
# 4     31-12-2024  403.84  423.79  427.93  402.54   76.83M   -3.25%
# ...          ...     ...     ...     ...     ...      ...      ...
# 1257  08-01-2020   32.81   31.58   33.23   31.22  467.99M    4.92%
# 1258  07-01-2020   31.27   30.76   31.44   30.22  273.14M    3.89%
# 1259  06-01-2020   30.10   29.36   30.10   29.33  152.36M    1.93%
# 1260  03-01-2020   29.53   29.37   30.27   29.13  266.92M    2.96%
# 1261  02-01-2020   28.68   28.30   28.71   28.11  143.38M    2.83%
#
# [1262 rows x 7 columns]

# %%
print(df8.info())  
print(df8.describe())  
print(df8.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262 entries, 0 to 1261
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1262 non-null   object
#  1   Price     1262 non-null   float64
#  2   Open      1262 non-null   float64
#  3   High      1262 non-null   float64
#  4   Low       1262 non-null   float64
#  5   Vol.      1262 non-null   object
#  6   Change %  1262 non-null   object
#  7   DPR       1262 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 79.0+ KB
# None
#              Price         Open         High          Low          DPR
# count  1262.000000  1262.000000  1262.000000  1262.000000  1262.000000
# mean    214.018431   214.073970   218.895816   208.922195     0.061384
# std      83.981506    84.156096    85.952117    82.018375     3.300652
# min      24.080000    24.980000    26.990000    23.370000   -12.788855
# ...

# %%
df9 = df8['Open'].rolling(10).mean()
df9
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 1257    34.158
# 1258    33.421
# 1259    32.822
# 1260    32.375
# 1261    31.913
# Name: Open, Length: 1262, dtype: float64

# %%
df9.plot()
# Out:
# <Axes: >

# %%
numeric_data = df8[['Open', 'Price', 'High', 'Low']]

# Step 3: Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Step 4: Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Stock Metrics')
plt.show()

# %%
df8['DPR'] = ((df8['Price'] - df8['Open']) / df8['Open']) * 100
df8['DPR']
# Out:
# 0      -2.826307
# 1      -2.870983
# 2       7.591486
# 3      -2.773648
# 4      -4.707520
#           ...
# 1257    3.894870
# 1258    1.657997
# 1259    2.520436
# 1260    0.544774
# 1261    1.342756
# Name: DPR, Length: 1262, dtype: float64

# %%
df8['DPR'].plot()
# Out:
# <Axes: >

# %%
df11 = pd.read_excel(r"C:\Users\varsh\Downloads\Amazon(Volume).xlsx")
df11
# Out:
#            Date    Vol.      Volume
# 0    2025-01-07  28.08M  28080000.0
# 1    2025-01-06  31.85M  31850000.0
# 2    2025-01-03  27.52M  27520000.0
# 3    2025-01-02  33.96M  33960000.0
# 4    2024-12-31  24.82M  24820000.0
# ...         ...     ...         ...
# 1257 2020-01-08  70.24M  70240000.0
# 1258 2020-01-07  82.68M  82680000.0
# 1259 2020-01-06  81.31M  81310000.0
# 1260 2020-01-03  75.33M  75330000.0
# 1261 2020-01-02  80.72M  80720000.0
#
# [1262 rows x 3 columns]

# %%
df11['Volume'].plot()
# Out:
# <Axes: >
